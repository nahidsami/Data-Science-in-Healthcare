# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Out:
# --2025-03-06 20:13:20--  https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘drugsCom_raw.zip’
#
# drugsCom_raw.zip        [             <=>    ]  41.00M  12.7MB/s    in 3.2s
#
# 2025-03-06 20:13:24 (12.7 MB/s) - ‘drugsCom_raw.zip’ saved [42989872]

# %% [markdown]
# # Dataset and Library
# The dataset that will be used as a sample in this notebook is the [Drug Review Dataset](https://archive.ics.uci.edu/dataset/462/drug+review+dataset+drugs+com) from the open source UCI Machine Learning Repository and [transformer](https://en.wikipedia.org/wiki/Transformer_(machine_learning_model)) models from the Python library,[huggingface](https://huggingface.co/transformers)

# %%
# !unzip drugsCom_raw.zip
# Out:
# Archive:  drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %%
# %%capture
# !pip install transformers

# %%
from transformers import pipeline
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ##Sentiment analysis using pretrained transformer models

# %%
medication_review_df = pd.read_csv('/content/drugsComTest_raw.tsv',sep="\t")
medication_review_df
# Out:
#        Unnamed: 0         drugName                     condition  \
# 0          163740      Mirtazapine                    Depression
# 1          206473       Mesalamine  Crohn's Disease, Maintenance
# 2          159672          Bactrim       Urinary Tract Infection
# 3           39293         Contrave                   Weight Loss
# 4           97768  Cyclafem 1 / 35                 Birth Control
# ...           ...              ...                           ...
# 53761      159999        Tamoxifen     Breast Cancer, Prevention
# 53762      140714     Escitalopram                       Anxiety
# 53763      130945   Levonorgestrel                 Birth Control
# 53764       47656       Tapentadol                          Pain
# 53765      113712        Arthrotec                      Sciatica
#
#                                                   review  rating  \
# 0      "I&#039;ve tried a few antidepressants over th...    10.0
# 1      "My son has Crohn&#039;s disease and has done ...     8.0
# 2                          "Quick reduction of symptoms"     9.0
# 3      "Contrave combines drugs that were used for al...     9.0
# 4      "I have been on this birth control for one cyc...     9.0
# ...                                                  ...     ...
# 53761  "I have taken Tamoxifen for 5 years. Side effe...    10.0
# 53762  "I&#039;ve been taking Lexapro (escitaploprgra...     9.0
# 53763  "I&#039;m married, 34 years old and I have no ...     8.0
# 53764  "I was prescribed Nucynta for severe neck/shou...     1.0
# 53765                                      "It works!!!"     9.0
#
#                      date  usefulCount
# 0       February 28, 2012           22
# 1            May 17, 2009           17
# 2      September 29, 2017            3
# 3           March 5, 2017           35
# 4        October 22, 2015            4
# ...                   ...          ...
# 53761  September 13, 2014           43
# 53762     October 8, 2016           11
# 53763   November 15, 2010            7
# 53764   November 28, 2011           20
# 53765  September 13, 2009           46
#
# [53766 rows x 7 columns]

# %%
medication_review_df.rename(columns={"Unnamed: 0": "uniqueId"},inplace=True)

# %%
medication_review_df = medication_review_df[:500]

# %%
bio_clinibert_classifier = pipeline("sentiment-analysis",model="okho0653/Bio_ClinicalBERT-zero-shot-sentiment-model",max_length=512, truncation =True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/706 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/358 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
rubert_classifier = pipeline("sentiment-analysis",model="blanchefort/rubert-base-cased-sentiment-med",max_length=512, truncation =True)
# Out:
# config.json:   0%|          | 0.00/944 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/495 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
roberta_classifier = pipeline("sentiment-analysis",model="cardiffnlp/twitter-roberta-base-sentiment",max_length=512, truncation =True)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
medication_review_df['review'][0]
# Out:
# '"I&#039;ve tried a few antidepressants over the years (citalopram, fluoxetine, amitriptyline), but none of those helped with my depression, insomnia &amp; anxiety. My doctor suggested and changed me onto 45mg mirtazapine and this medicine has saved my life. Thankfully I have had no side effects especially the most common - weight gain, I&#039;ve actually lost alot of weight. I still have suicidal thoughts but mirtazapine has saved me."'

# %%
bio_clinibert_classifier.predict(medication_review_df['review'][0])
# Out:
# [{'label': 'LABEL_0', 'score': 0.5981781482696533}]

# %%
rubert_classifier.predict(medication_review_df['review'][0])
# Out:
# [{'label': 'POSITIVE', 'score': 0.7634803056716919}]

# %%
roberta_classifier.predict(medication_review_df['review'][0])
# Out:
# [{'label': 'LABEL_2', 'score': 0.7081272006034851}]

# %%
medication_review_df['review'][10]
# Out:
# '"Holy Hell is exactly how I feel. I had been taking Brisdelle for 1.5 years. The hot flashes did indeed subside - however, the side affects of this medicine coupled with the fact Noven was acquired by YET another pharmaceutical company - YOU CAN&#039;T PLACE A REP IN THE AREA, DISTRIBUTE YOUR DRUGS, AND THEN FIRE HER-AND NOT REPLACE THEREFORE there is NO medicine or support here. You dumped this drug in the Dr&#039;s hands and walked away. After calling Sebula - you act like you don&#039;t even care. You have made it impossible to obtain this. I happen to think this is illegal.  I just decided to wean myself off this and Premarin. It has been nothing short of a nightmare. If you don&#039;t need this drug- DON&#039;T START. Seriously."'

# %%
bio_clinibert_classifier.predict(medication_review_df['review'][10])
# Out:
# [{'label': 'LABEL_0', 'score': 0.5748332142829895}]

# %%
rubert_classifier.predict(medication_review_df['review'][10])
# Out:
# [{'label': 'NEUTRAL', 'score': 0.41431963443756104}]

# %%
roberta_classifier.predict(medication_review_df['review'][10])
# Out:
# [{'label': 'LABEL_0', 'score': 0.9392552375793457}]

# %%
medication_review_df['review'][100]
# Out:
# '"My 5 year old son was diagnosed with ADHD just yesterday, the Behavior Specialist said his was one of the worst cases that she had seen in a while, she had suggested putting him on a stimulant medication, I told her i would like to  a non-stimulant medication first and she prescribed him Kapvay. My son took it for the first time last night before bed, he went right to sleep and when he woke up this morning he was the calmest most pleasant, helpful and nicest he had ever been in his life. I could not believe the overnight change. I&#039;m so glad it worked so fast, he has not gotten in trouble once today which is a new record! His teachers are going to be thrilled on Monday! Thank you to the makers of Clonidine!"'

# %%
bio_clinibert_classifier.predict(medication_review_df['review'][100])
# Out:
# [{'label': 'LABEL_0', 'score': 0.5827550292015076}]

# %%
rubert_classifier.predict(medication_review_df['review'][100])
# Out:
# [{'label': 'POSITIVE', 'score': 0.914296567440033}]

# %%
roberta_classifier.predict(medication_review_df['review'][100])
# Out:
# [{'label': 'LABEL_2', 'score': 0.9514226913452148}]

# %%
tqdm.pandas(desc='My bar!')
medication_review_df['rubert_sentiment'] = medication_review_df['review'].progress_apply(lambda x : rubert_classifier.predict(x))
# Out:
# My bar!:   1%|          | 4/500 [00:00<00:13, 38.15it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# My bar!: 100%|██████████| 500/500 [00:06<00:00, 74.24it/s]
# <ipython-input-23-05a446748314>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medication_review_df['rubert_sentiment'] = medication_review_df['review'].progress_apply(lambda x : rubert_classifier.predict(x))

# %%
medication_review_df
# Out:
#      uniqueId                drugName                     condition  \
# 0      163740             Mirtazapine                    Depression
# 1      206473              Mesalamine  Crohn's Disease, Maintenance
# 2      159672                 Bactrim       Urinary Tract Infection
# 3       39293                Contrave                   Weight Loss
# 4       97768         Cyclafem 1 / 35                 Birth Control
# ..        ...                     ...                           ...
# 495     12695              Etanercept          Rheumatoid Arthritis
# 496     54827  Bupropion / naltrexone                   Weight Loss
# 497    230865             Milnacipran                   ibromyalgia
# 498     30138                Klonopin               Bipolar Disorde
# 499    151470                 Chantix             Smoking Cessation
#
#                                                 review  rating  \
# 0    "I&#039;ve tried a few antidepressants over th...    10.0
# 1    "My son has Crohn&#039;s disease and has done ...     8.0
# 2                        "Quick reduction of symptoms"     9.0
# 3    "Contrave combines drugs that were used for al...     9.0
# 4    "I have been on this birth control for one cyc...     9.0
# ..                                                 ...     ...
# 495  "My husband has RA.    His doctor sent him to ...     3.0
# 496  "Well just have start by saying so far so good...     9.0
# 497  "Very effective for fibromyalgia pain. Does no...     9.0
# 498                                           "Great."    10.0
# 499  "I smoked for forty years the last 10 ,2 1/2 p...    10.0
#
#                    date  usefulCount  \
# 0     February 28, 2012           22
# 1          May 17, 2009           17
# 2    September 29, 2017            3
# 3         March 5, 2017           35
# 4      October 22, 2015            4
# ..                  ...          ...
# 495        May 31, 2015           35
# 496   February 16, 2017           30
# 497   September 7, 2015           38
# 498  September 27, 2013           23
# 499       April 5, 2016           34
#
#                                       rubert_sentiment
# 0    [{'label': 'POSITIVE', 'score': 0.763480305671...
# 1    [{'label': 'POSITIVE', 'score': 0.978934466838...
# 2    [{'label': 'POSITIVE', 'score': 0.722793757915...
# 3    [{'label': 'POSITIVE', 'score': 0.694053292274...
# 4    [{'label': 'POSITIVE', 'score': 0.449853628873...
# ..                                                 ...
# 495  [{'label': 'NEGATIVE', 'score': 0.571891546249...
# 496  [{'label': 'POSITIVE', 'score': 0.963343679904...
# 497  [{'label': 'POSITIVE', 'score': 0.381170183420...
# 498  [{'label': 'NEGATIVE', 'score': 0.927029669284...
# 499  [{'label': 'POSITIVE', 'score': 0.975741982460...
#
# [500 rows x 8 columns]

# %%
medication_review_df['review'][498]
# Out:
# '"Great."'

# %%
medication_review_df['rubert_sentiment'][498]
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9270296692848206}]

# %%
medication_review_df['rubert_label'] = medication_review_df['rubert_sentiment'].apply(lambda x : x[0]['label'])
# Out:
# <ipython-input-27-e4eff27d243c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medication_review_df['rubert_label'] = medication_review_df['rubert_sentiment'].apply(lambda x : x[0]['label'])

# %%
medication_review_df
# Out:
#      uniqueId                drugName                     condition  \
# 0      163740             Mirtazapine                    Depression
# 1      206473              Mesalamine  Crohn's Disease, Maintenance
# 2      159672                 Bactrim       Urinary Tract Infection
# 3       39293                Contrave                   Weight Loss
# 4       97768         Cyclafem 1 / 35                 Birth Control
# ..        ...                     ...                           ...
# 495     12695              Etanercept          Rheumatoid Arthritis
# 496     54827  Bupropion / naltrexone                   Weight Loss
# 497    230865             Milnacipran                   ibromyalgia
# 498     30138                Klonopin               Bipolar Disorde
# 499    151470                 Chantix             Smoking Cessation
#
#                                                 review  rating  \
# 0    "I&#039;ve tried a few antidepressants over th...    10.0
# 1    "My son has Crohn&#039;s disease and has done ...     8.0
# 2                        "Quick reduction of symptoms"     9.0
# 3    "Contrave combines drugs that were used for al...     9.0
# 4    "I have been on this birth control for one cyc...     9.0
# ..                                                 ...     ...
# 495  "My husband has RA.    His doctor sent him to ...     3.0
# 496  "Well just have start by saying so far so good...     9.0
# 497  "Very effective for fibromyalgia pain. Does no...     9.0
# 498                                           "Great."    10.0
# 499  "I smoked for forty years the last 10 ,2 1/2 p...    10.0
#
#                    date  usefulCount  \
# 0     February 28, 2012           22
# 1          May 17, 2009           17
# 2    September 29, 2017            3
# 3         March 5, 2017           35
# 4      October 22, 2015            4
# ..                  ...          ...
# 495        May 31, 2015           35
# 496   February 16, 2017           30
# 497   September 7, 2015           38
# 498  September 27, 2013           23
# 499       April 5, 2016           34
#
#                                       rubert_sentiment rubert_label
# 0    [{'label': 'POSITIVE', 'score': 0.763480305671...     POSITIVE
# 1    [{'label': 'POSITIVE', 'score': 0.978934466838...     POSITIVE
# 2    [{'label': 'POSITIVE', 'score': 0.722793757915...     POSITIVE
# 3    [{'label': 'POSITIVE', 'score': 0.694053292274...     POSITIVE
# 4    [{'label': 'POSITIVE', 'score': 0.449853628873...     POSITIVE
# ..                                                 ...          ...
# 495  [{'label': 'NEGATIVE', 'score': 0.571891546249...     NEGATIVE
# 496  [{'label': 'POSITIVE', 'score': 0.963343679904...     POSITIVE
# 497  [{'label': 'POSITIVE', 'score': 0.381170183420...     POSITIVE
# 498  [{'label': 'NEGATIVE', 'score': 0.927029669284...     NEGATIVE
# 499  [{'label': 'POSITIVE', 'score': 0.975741982460...     POSITIVE
#
# [500 rows x 9 columns]

# %%
medication_review_df[:50]
# Out:
#     uniqueId                          drugName                     condition  \
# 0     163740                       Mirtazapine                    Depression
# 1     206473                        Mesalamine  Crohn's Disease, Maintenance
# 2     159672                           Bactrim       Urinary Tract Infection
# 3      39293                          Contrave                   Weight Loss
# 4      97768                   Cyclafem 1 / 35                 Birth Control
# 5     208087                           Zyclara                     Keratosis
# 6     215892                            Copper                 Birth Control
# 7     169852                     Amitriptyline           Migraine Prevention
# 8      23295                         Methadone             Opiate Withdrawal
# 9      71428                            Levora                 Birth Control
# 10    196802                        Paroxetine                   Hot Flashes
# 11     31947                        Miconazole       Vaginal Yeast Infection
# 12      4907                            Belviq                   Weight Loss
# 13     66736                          Seroquel       Schizoaffective Disorde
# 14     97013                            Ambien                      Insomnia
# 15    213376                           Nuvigil                    Narcolepsy
# 16    151674                           Chantix             Smoking Cessation
# 17     33173             Microgestin Fe 1 / 20                          Acne
# 18     30401                          Klonopin               Bipolar Disorde
# 19    152490                     Ciprofloxacin       Urinary Tract Infection
# 20    231397                         Trazodone                      Insomnia
# 21     38116                         EnteraGam      Irritable Bowel Syndrome
# 22    102969                      Aripiprazole               Bipolar Disorde
# 23     12626                      Cyclosporine    Keratoconjunctivitis Sicca
# 24    190527                        Oxybutynin                 Hyperhidrosis
# 25    229975                        Lurasidone               Bipolar Disorde
# 26    173391                        Clonazepam                 Panic Disorde
# 27     35608                        Ciclopirox     Onychomycosis, Fingernail
# 28    187230                    Sodium oxybate                    Narcolepsy
# 29    211675                       Lamotrigine               Bipolar Disorde
# 30     79865                 Blisovi Fe 1 / 20                 Birth Control
# 31     27607                        Ivermectin                       Rosacea
# 32    207923             Suprep Bowel Prep Kit             Bowel Preparation
# 33    156919                          Movantik    Constipation, Drug Induced
# 34     77164                        Lorcaserin                           NaN
# 35    101149                             Actos              Diabetes, Type 2
# 36    178004                        Duloxetine                          Pain
# 37     60341                          NuvaRing                 Birth Control
# 38    141462                      Escitalopram                    Depression
# 39    133539                       Tesamorelin                 Lipodystrophy
# 40    191095                           Campral            Alcohol Dependence
# 41     50229                        Gabapentin               Bipolar Disorde
# 42    130301                    Levonorgestrel       Emergency Contraception
# 43    101371                             Aubra                 Birth Control
# 44     79569                   Plan B One-Step       Emergency Contraception
# 45     17957  Ethinyl estradiol / etonogestrel                 Birth Control
# 46    219567           Microgestin Fe 1.5 / 30                 Birth Control
# 47    171525                        Wellbutrin      Major Depressive Disorde
# 48    173027                        Clonazepam                       Anxiety
# 49    202002    Benzoyl peroxide / clindamycin                          Acne
#
#                                                review  rating  \
# 0   "I&#039;ve tried a few antidepressants over th...    10.0
# 1   "My son has Crohn&#039;s disease and has done ...     8.0
# 2                       "Quick reduction of symptoms"     9.0
# 3   "Contrave combines drugs that were used for al...     9.0
# 4   "I have been on this birth control for one cyc...     9.0
# 5   "4 days in on first 2 weeks.  Using on arms an...     4.0
# 6   "I&#039;ve had the copper coil for about 3 mon...     6.0
# 7   "This has been great for me. I&#039;ve been on...     9.0
# 8   "Ive been on Methadone for over ten years and ...     7.0
# 9   "I was on this pill for almost two years. It d...     2.0
# 10  "Holy Hell is exactly how I feel. I had been t...     1.0
# 11  "Honestly its day one on the 3 day treatment. ...     6.0
# 12  "This is a waste of money.  Did not curb my ap...     1.0
# 13                 "No problems, watch what you eat."    10.0
# 14  "Ditto on rebound sleepless when discontinued....     2.0
# 15  "A doctor in the ER prescribed me 200 mg of Pr...     9.0
# 16  "I smoked for 50+ years.  Took it for one week...    10.0
# 17  "So I was on Ginanvi for about 3 months before...     3.0
# 18  "This medication helped me  sleep, but eventua...     6.0
# 19  "After just 1 dose of this ciprofloxacn, I fel...    10.0
# 20  "If I could give it a 0, I would absolutely do...     1.0
# 21  "I am so happy with the samples provided by my...     9.0
# 22  "After a few days and it &quot;kicked in,&quot...     1.0
# 23        "They didn&#039;t help my dry eyes at all."     1.0
# 24  "This drug is pretty amazing. I&#039;ve had hy...     9.0
# 25  "This medication should not be being prescribe...     6.0
# 26   "klonopin has definitely given me my life back!"    10.0
# 27  "Worked quickly and well. I learned by trial t...     8.0
# 28  "2.75g x 2 every night for five years. Deeper ...    10.0
# 29  "I am a 25 year old female. I was diagnosed wi...     7.0
# 30  "I absolutely love this product and recommend ...    10.0
# 31  "I&#039;ve had rosacea for almost 20 years and...    10.0
# 32  "This stuff wasn&#039;t too bad!  I had a hard...     8.0
# 33  "my advice on movantik is understand that mova...     1.0
# 34  "Have had back and leg pain and sometimes arm ...     5.0
# 35  "Have been on Actos for almost a year, gained ...     4.0
# 36  "Been on 30mg Cymbalta for 2 weeks. Started ge...     9.0
# 37  "I was on this for 5 years (and birth control ...     7.0
# 38  "I am a 22 year old female college student. I ...     9.0
# 39  "I have been administering Egrifta now for 2 1...     3.0
# 40  "Been a heavy drinker for over 6 years since a...    10.0
# 41  "I started taking gabapentin experimentally to...     8.0
# 42  "I want to share my experience to possibly eas...    10.0
# 43  "I&#039;m absolutely DONE taking this horrible...     1.0
# 44  "Our condom seemed to not have worked properly...     8.0
# 45  "I started on the oral contraceptive pill but ...    10.0
# 46  "About two months ago I had to switch from LoL...     1.0
# 47  "Coming from a very problematic childhood, I&#...     8.0
# 48                                     "Works for me"     6.0
# 49  "My GP had prescribed this to me at my request...     4.0
#
#                   date  usefulCount  \
# 0    February 28, 2012           22
# 1         May 17, 2009           17
# 2   September 29, 2017            3
# 3        March 5, 2017           35
# 4     October 22, 2015            4
# 5         July 3, 2014           13
# 6         June 6, 2016            1
# 7       April 21, 2009           32
# 8     October 18, 2016           21
# 9       April 16, 2011            3
# 10   February 22, 2017           17
# 11         May 7, 2015            7
# 12  September 23, 2014           57
# 13     October 8, 2014           19
# 14    January 13, 2015           44
# 15       June 30, 2010           14
# 16   February 14, 2015           26
# 17       June 22, 2017            1
# 18       July 14, 2009           24
# 19        June 9, 2010            9
# 20    October 18, 2016           15
# 21     January 1, 2015           43
# 22   February 10, 2010           27
# 23   December 31, 2015           17
# 24        May 30, 2017           10
# 25   February 11, 2017           18
# 26      April 19, 2008           47
# 27        June 2, 2016           38
# 28    January 10, 2013           19
# 29   November 22, 2017            1
# 30    November 3, 2017            4
# 31       April 1, 2016           19
# 32   February 18, 2015           15
# 33     August 26, 2016           24
# 34        May 27, 2014           21
# 35        June 9, 2010           42
# 36      March 27, 2012           32
# 37       June 17, 2011            0
# 38      April 29, 2014           32
# 39    January 11, 2012           12
# 40     August 23, 2013           55
# 41  September 24, 2014           75
# 42   December 28, 2013           20
# 43   December 13, 2015            6
# 44    January 19, 2012           21
# 45   December 13, 2012            4
# 46    October 31, 2016            4
# 47       March 6, 2015           49
# 48      March 24, 2013           20
# 49    January 26, 2017            2
#
#                                      rubert_sentiment rubert_label
# 0   [{'label': 'POSITIVE', 'score': 0.763480305671...     POSITIVE
# 1   [{'label': 'POSITIVE', 'score': 0.978934466838...     POSITIVE
# 2   [{'label': 'POSITIVE', 'score': 0.722793757915...     POSITIVE
# 3   [{'label': 'POSITIVE', 'score': 0.694053292274...     POSITIVE
# 4   [{'label': 'POSITIVE', 'score': 0.449853628873...     POSITIVE
# 5   [{'label': 'NEGATIVE', 'score': 0.373242855072...     NEGATIVE
# 6   [{'label': 'POSITIVE', 'score': 0.516627132892...     POSITIVE
# 7   [{'label': 'POSITIVE', 'score': 0.954067945480...     POSITIVE
# 8   [{'label': 'NEGATIVE', 'score': 0.709616959095...     NEGATIVE
# 9   [{'label': 'POSITIVE', 'score': 0.701549470424...     POSITIVE
# 10  [{'label': 'NEUTRAL', 'score': 0.4143196344375...      NEUTRAL
# 11  [{'label': 'POSITIVE', 'score': 0.693522274494...     POSITIVE
# 12  [{'label': 'NEGATIVE', 'score': 0.696613311767...     NEGATIVE
# 13  [{'label': 'NEGATIVE', 'score': 0.609581768512...     NEGATIVE
# 14  [{'label': 'POSITIVE', 'score': 0.980249524116...     POSITIVE
# 15  [{'label': 'POSITIVE', 'score': 0.508652389049...     POSITIVE
# 16  [{'label': 'POSITIVE', 'score': 0.734166800975...     POSITIVE
# 17  [{'label': 'NEUTRAL', 'score': 0.4338773787021...      NEUTRAL
# 18  [{'label': 'NEGATIVE', 'score': 0.408370584249...     NEGATIVE
# 19  [{'label': 'NEGATIVE', 'score': 0.914646863937...     NEGATIVE
# 20  [{'label': 'NEUTRAL', 'score': 0.4221347570419...      NEUTRAL
# 21  [{'label': 'POSITIVE', 'score': 0.697995305061...     POSITIVE
# 22  [{'label': 'NEGATIVE', 'score': 0.390619486570...     NEGATIVE
# 23  [{'label': 'NEGATIVE', 'score': 0.429456979036...     NEGATIVE
# 24  [{'label': 'POSITIVE', 'score': 0.581856489181...     POSITIVE
# 25  [{'label': 'POSITIVE', 'score': 0.860096216201...     POSITIVE
# 26  [{'label': 'NEGATIVE', 'score': 0.773162424564...     NEGATIVE
# 27  [{'label': 'NEUTRAL', 'score': 0.3993448019027...      NEUTRAL
# 28  [{'label': 'POSITIVE', 'score': 0.546482563018...     POSITIVE
# 29  [{'label': 'NEGATIVE', 'score': 0.526444256305...     NEGATIVE
# 30  [{'label': 'POSITIVE', 'score': 0.910107254981...     POSITIVE
# 31  [{'label': 'POSITIVE', 'score': 0.976852655410...     POSITIVE
# 32  [{'label': 'NEUTRAL', 'score': 0.3808734416961...      NEUTRAL
# 33  [{'label': 'NEGATIVE', 'score': 0.611960291862...     NEGATIVE
# 34  [{'label': 'NEGATIVE', 'score': 0.859542250633...     NEGATIVE
# 35  [{'label': 'POSITIVE', 'score': 0.975844681262...     POSITIVE
# 36  [{'label': 'NEGATIVE', 'score': 0.419360250234...     NEGATIVE
# 37  [{'label': 'NEUTRAL', 'score': 0.4048631489276...      NEUTRAL
# 38  [{'label': 'POSITIVE', 'score': 0.954817116260...     POSITIVE
# 39  [{'label': 'POSITIVE', 'score': 0.722794234752...     POSITIVE
# 40  [{'label': 'POSITIVE', 'score': 0.793244779109...     POSITIVE
# 41  [{'label': 'POSITIVE', 'score': 0.952444255352...     POSITIVE
# 42  [{'label': 'NEGATIVE', 'score': 0.450625628232...     NEGATIVE
# 43  [{'label': 'NEUTRAL', 'score': 0.3914872109889...      NEUTRAL
# 44  [{'label': 'NEUTRAL', 'score': 0.4065571427345...      NEUTRAL
# 45  [{'label': 'NEGATIVE', 'score': 0.605369448661...     NEGATIVE
# 46  [{'label': 'POSITIVE', 'score': 0.447853893041...     POSITIVE
# 47  [{'label': 'POSITIVE', 'score': 0.656590938568...     POSITIVE
# 48  [{'label': 'POSITIVE', 'score': 0.973713636398...     POSITIVE
# 49  [{'label': 'NEUTRAL', 'score': 0.4052238166332...      NEUTRAL

# %%
tqdm.pandas(desc='My bar!')
medication_review_df['roberta_sentiment'] = medication_review_df['review'].progress_apply(lambda x : roberta_classifier.predict(x))
# Out:
# My bar!: 100%|██████████| 500/500 [00:05<00:00, 97.55it/s]
# <ipython-input-30-ad309e1143fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medication_review_df['roberta_sentiment'] = medication_review_df['review'].progress_apply(lambda x : roberta_classifier.predict(x))

# %%
medication_review_df
# Out:
#      uniqueId                drugName                     condition  \
# 0      163740             Mirtazapine                    Depression
# 1      206473              Mesalamine  Crohn's Disease, Maintenance
# 2      159672                 Bactrim       Urinary Tract Infection
# 3       39293                Contrave                   Weight Loss
# 4       97768         Cyclafem 1 / 35                 Birth Control
# ..        ...                     ...                           ...
# 495     12695              Etanercept          Rheumatoid Arthritis
# 496     54827  Bupropion / naltrexone                   Weight Loss
# 497    230865             Milnacipran                   ibromyalgia
# 498     30138                Klonopin               Bipolar Disorde
# 499    151470                 Chantix             Smoking Cessation
#
#                                                 review  rating  \
# 0    "I&#039;ve tried a few antidepressants over th...    10.0
# 1    "My son has Crohn&#039;s disease and has done ...     8.0
# 2                        "Quick reduction of symptoms"     9.0
# 3    "Contrave combines drugs that were used for al...     9.0
# 4    "I have been on this birth control for one cyc...     9.0
# ..                                                 ...     ...
# 495  "My husband has RA.    His doctor sent him to ...     3.0
# 496  "Well just have start by saying so far so good...     9.0
# 497  "Very effective for fibromyalgia pain. Does no...     9.0
# 498                                           "Great."    10.0
# 499  "I smoked for forty years the last 10 ,2 1/2 p...    10.0
#
#                    date  usefulCount  \
# 0     February 28, 2012           22
# 1          May 17, 2009           17
# 2    September 29, 2017            3
# 3         March 5, 2017           35
# 4      October 22, 2015            4
# ..                  ...          ...
# 495        May 31, 2015           35
# 496   February 16, 2017           30
# 497   September 7, 2015           38
# 498  September 27, 2013           23
# 499       April 5, 2016           34
#
#                                       rubert_sentiment rubert_label  \
# 0    [{'label': 'POSITIVE', 'score': 0.763480305671...     POSITIVE
# 1    [{'label': 'POSITIVE', 'score': 0.978934466838...     POSITIVE
# 2    [{'label': 'POSITIVE', 'score': 0.722793757915...     POSITIVE
# 3    [{'label': 'POSITIVE', 'score': 0.694053292274...     POSITIVE
# 4    [{'label': 'POSITIVE', 'score': 0.449853628873...     POSITIVE
# ..                                                 ...          ...
# 495  [{'label': 'NEGATIVE', 'score': 0.571891546249...     NEGATIVE
# 496  [{'label': 'POSITIVE', 'score': 0.963343679904...     POSITIVE
# 497  [{'label': 'POSITIVE', 'score': 0.381170183420...     POSITIVE
# 498  [{'label': 'NEGATIVE', 'score': 0.927029669284...     NEGATIVE
# 499  [{'label': 'POSITIVE', 'score': 0.975741982460...     POSITIVE
#
#                                      roberta_sentiment
# 0    [{'label': 'LABEL_2', 'score': 0.7081272006034...
# 1    [{'label': 'LABEL_2', 'score': 0.9489813446998...
# 2    [{'label': 'LABEL_1', 'score': 0.7108302712440...
# 3    [{'label': 'LABEL_2', 'score': 0.4569101929664...
# 4    [{'label': 'LABEL_2', 'score': 0.9641554951667...
# ..                                                 ...
# 495  [{'label': 'LABEL_0', 'score': 0.6601070761680...
# 496  [{'label': 'LABEL_2', 'score': 0.8409106731414...
# 497  [{'label': 'LABEL_1', 'score': 0.4641804993152...
# 498  [{'label': 'LABEL_2', 'score': 0.7443177103996...
# 499  [{'label': 'LABEL_2', 'score': 0.9009679555892...
#
# [500 rows x 10 columns]

# %%
medication_review_df['roberta_label'] = medication_review_df['roberta_sentiment'].apply(lambda x : x[0]['label'])
# Out:
# <ipython-input-32-ab80a3e61cc1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medication_review_df['roberta_label'] = medication_review_df['roberta_sentiment'].apply(lambda x : x[0]['label'])

# %%
medication_review_df
# Out:
#      uniqueId                drugName                     condition  \
# 0      163740             Mirtazapine                    Depression
# 1      206473              Mesalamine  Crohn's Disease, Maintenance
# 2      159672                 Bactrim       Urinary Tract Infection
# 3       39293                Contrave                   Weight Loss
# 4       97768         Cyclafem 1 / 35                 Birth Control
# ..        ...                     ...                           ...
# 495     12695              Etanercept          Rheumatoid Arthritis
# 496     54827  Bupropion / naltrexone                   Weight Loss
# 497    230865             Milnacipran                   ibromyalgia
# 498     30138                Klonopin               Bipolar Disorde
# 499    151470                 Chantix             Smoking Cessation
#
#                                                 review  rating  \
# 0    "I&#039;ve tried a few antidepressants over th...    10.0
# 1    "My son has Crohn&#039;s disease and has done ...     8.0
# 2                        "Quick reduction of symptoms"     9.0
# 3    "Contrave combines drugs that were used for al...     9.0
# 4    "I have been on this birth control for one cyc...     9.0
# ..                                                 ...     ...
# 495  "My husband has RA.    His doctor sent him to ...     3.0
# 496  "Well just have start by saying so far so good...     9.0
# 497  "Very effective for fibromyalgia pain. Does no...     9.0
# 498                                           "Great."    10.0
# 499  "I smoked for forty years the last 10 ,2 1/2 p...    10.0
#
#                    date  usefulCount  \
# 0     February 28, 2012           22
# 1          May 17, 2009           17
# 2    September 29, 2017            3
# 3         March 5, 2017           35
# 4      October 22, 2015            4
# ..                  ...          ...
# 495        May 31, 2015           35
# 496   February 16, 2017           30
# 497   September 7, 2015           38
# 498  September 27, 2013           23
# 499       April 5, 2016           34
#
#                                       rubert_sentiment rubert_label  \
# 0    [{'label': 'POSITIVE', 'score': 0.763480305671...     POSITIVE
# 1    [{'label': 'POSITIVE', 'score': 0.978934466838...     POSITIVE
# 2    [{'label': 'POSITIVE', 'score': 0.722793757915...     POSITIVE
# 3    [{'label': 'POSITIVE', 'score': 0.694053292274...     POSITIVE
# 4    [{'label': 'POSITIVE', 'score': 0.449853628873...     POSITIVE
# ..                                                 ...          ...
# 495  [{'label': 'NEGATIVE', 'score': 0.571891546249...     NEGATIVE
# 496  [{'label': 'POSITIVE', 'score': 0.963343679904...     POSITIVE
# 497  [{'label': 'POSITIVE', 'score': 0.381170183420...     POSITIVE
# 498  [{'label': 'NEGATIVE', 'score': 0.927029669284...     NEGATIVE
# 499  [{'label': 'POSITIVE', 'score': 0.975741982460...     POSITIVE
#
#                                      roberta_sentiment roberta_label
# 0    [{'label': 'LABEL_2', 'score': 0.7081272006034...       LABEL_2
# 1    [{'label': 'LABEL_2', 'score': 0.9489813446998...       LABEL_2
# 2    [{'label': 'LABEL_1', 'score': 0.7108302712440...       LABEL_1
# 3    [{'label': 'LABEL_2', 'score': 0.4569101929664...       LABEL_2
# 4    [{'label': 'LABEL_2', 'score': 0.9641554951667...       LABEL_2
# ..                                                 ...           ...
# 495  [{'label': 'LABEL_0', 'score': 0.6601070761680...       LABEL_0
# 496  [{'label': 'LABEL_2', 'score': 0.8409106731414...       LABEL_2
# 497  [{'label': 'LABEL_1', 'score': 0.4641804993152...       LABEL_1
# 498  [{'label': 'LABEL_2', 'score': 0.7443177103996...       LABEL_2
# 499  [{'label': 'LABEL_2', 'score': 0.9009679555892...       LABEL_2
#
# [500 rows x 11 columns]

# %%
medication_review_df.replace({'LABEL_2':'Positive','LABEL_0':'Negative','LABEL_1':'Neutral'})
# Out:
#      uniqueId                drugName                     condition  \
# 0      163740             Mirtazapine                    Depression
# 1      206473              Mesalamine  Crohn's Disease, Maintenance
# 2      159672                 Bactrim       Urinary Tract Infection
# 3       39293                Contrave                   Weight Loss
# 4       97768         Cyclafem 1 / 35                 Birth Control
# ..        ...                     ...                           ...
# 495     12695              Etanercept          Rheumatoid Arthritis
# 496     54827  Bupropion / naltrexone                   Weight Loss
# 497    230865             Milnacipran                   ibromyalgia
# 498     30138                Klonopin               Bipolar Disorde
# 499    151470                 Chantix             Smoking Cessation
#
#                                                 review  rating  \
# 0    "I&#039;ve tried a few antidepressants over th...    10.0
# 1    "My son has Crohn&#039;s disease and has done ...     8.0
# 2                        "Quick reduction of symptoms"     9.0
# 3    "Contrave combines drugs that were used for al...     9.0
# 4    "I have been on this birth control for one cyc...     9.0
# ..                                                 ...     ...
# 495  "My husband has RA.    His doctor sent him to ...     3.0
# 496  "Well just have start by saying so far so good...     9.0
# 497  "Very effective for fibromyalgia pain. Does no...     9.0
# 498                                           "Great."    10.0
# 499  "I smoked for forty years the last 10 ,2 1/2 p...    10.0
#
#                    date  usefulCount  \
# 0     February 28, 2012           22
# 1          May 17, 2009           17
# 2    September 29, 2017            3
# 3         March 5, 2017           35
# 4      October 22, 2015            4
# ..                  ...          ...
# 495        May 31, 2015           35
# 496   February 16, 2017           30
# 497   September 7, 2015           38
# 498  September 27, 2013           23
# 499       April 5, 2016           34
#
#                                       rubert_sentiment rubert_label  \
# 0    [{'label': 'POSITIVE', 'score': 0.763480305671...     POSITIVE
# 1    [{'label': 'POSITIVE', 'score': 0.978934466838...     POSITIVE
# 2    [{'label': 'POSITIVE', 'score': 0.722793757915...     POSITIVE
# 3    [{'label': 'POSITIVE', 'score': 0.694053292274...     POSITIVE
# 4    [{'label': 'POSITIVE', 'score': 0.449853628873...     POSITIVE
# ..                                                 ...          ...
# 495  [{'label': 'NEGATIVE', 'score': 0.571891546249...     NEGATIVE
# 496  [{'label': 'POSITIVE', 'score': 0.963343679904...     POSITIVE
# 497  [{'label': 'POSITIVE', 'score': 0.381170183420...     POSITIVE
# 498  [{'label': 'NEGATIVE', 'score': 0.927029669284...     NEGATIVE
# 499  [{'label': 'POSITIVE', 'score': 0.975741982460...     POSITIVE
#
#                                      roberta_sentiment roberta_label
# 0    [{'label': 'LABEL_2', 'score': 0.7081272006034...      Positive
# 1    [{'label': 'LABEL_2', 'score': 0.9489813446998...      Positive
# 2    [{'label': 'LABEL_1', 'score': 0.7108302712440...       Neutral
# 3    [{'label': 'LABEL_2', 'score': 0.4569101929664...      Positive
# 4    [{'label': 'LABEL_2', 'score': 0.9641554951667...      Positive
# ..                                                 ...           ...
# 495  [{'label': 'LABEL_0', 'score': 0.6601070761680...      Negative
# 496  [{'label': 'LABEL_2', 'score': 0.8409106731414...      Positive
# 497  [{'label': 'LABEL_1', 'score': 0.4641804993152...       Neutral
# 498  [{'label': 'LABEL_2', 'score': 0.7443177103996...      Positive
# 499  [{'label': 'LABEL_2', 'score': 0.9009679555892...      Positive
#
# [500 rows x 11 columns]

# %%
medication_review_df['roberta_sentiment'][498]
# Out:
# [{'label': 'LABEL_2', 'score': 0.7443177103996277}]

# %%
print(medication_review_df['review'][497])
medication_review_df['roberta_sentiment'][497]
# Out:
# "Very effective for fibromyalgia pain. Does not help with fatigue."
# [{'label': 'LABEL_1', 'score': 0.46418049931526184}]
